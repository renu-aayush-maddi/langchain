# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is **Paris**.

# %%
model.invoke("Write a 300 word essay on the importance of education in society.")
# Out:
# AIMessage(content='Education is the bedrock of a thriving society, acting as the primary catalyst for progress, individual empowerment, and collective well-being. Its importance cannot be overstated, as it shapes not only the intellectual capacity of its citizens but also their ethical compass and their ability to contribute meaningfully to the world.\n\nAt its most fundamental level, education equips individuals with the knowledge and skills necessary to navigate life. Literacy and numeracy are foundational, enabling participation in the economy and informed decision-making. Beyond these basics, education fosters critical thinking, problem-solving abilities, and creativity, essential for tackling complex societal challenges. An educated populace is better equipped to understand scientific advancements, appreciate cultural diversity, and engage in civic discourse.\n\nFurthermore, education is a powerful engine for social mobility and equality. It provides opportunities for individuals from all backgrounds to break cycles of poverty and achieve their full potential. By offering a level playing field, education can reduce disparities and build a more just and equitable society. It empowers individuals to question injustices, advocate for their rights, and participate actively in democratic processes, strengthening the fabric of governance.\n\nBeyond individual benefits, education fuels innovation and economic growth. A skilled workforce drives industries, fosters entrepreneurship, and contributes to national prosperity. Moreover, educated citizens are more likely to be engaged in their communities, volunteer, and contribute to social cohesion. In essence, education is an investment in the future, cultivating informed, responsible, and capable individuals who are the architects of a brighter tomorrow.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e2295-a0d4-74e2-969f-1b0563d1a0c7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 296, 'total_tokens': 313, 'input_token_details': {'cache_read': 0}})

# %%
for chunk in model.stream("Write a 300 word essay on the importance of education in society."):
    print(chunk.content, end="|" ,flush=True)
# Out:
# Education| is the bedrock of a thriving society, a transformative force that shapes individuals and prop|els collective progress. Its importance extends far beyond the acquisition of knowledge; it cultivates critical thinking, fosters innovation, and empowers citizens to actively participate in democratic processes. Without a well-educated populace, societies risk stagnation, increased inequality, and a| diminished capacity to address complex global challenges.
#
# At its core, education equips individuals with the skills and understanding necessary to navigate the complexities of the modern world. Literacy, numeracy, and problem-solving abilities are fundamental tools that unlock opportunities for personal| and professional growth. Beyond these practical skills, education nurtures curiosity, encourages creativity, and instills a lifelong love of learning. This intellectual development is crucial for adapting to rapidly evolving landscapes, both in the workplace and in personal life.
#
# Furthermore, education plays| a vital role in fostering social cohesion and promoting equality. By providing access to knowledge and opportunities, it can break cycles of poverty and disadvantage, offering a pathway to social mobility. An educated society is more likely to be tolerant, understanding, and respectful| of diverse perspectives. It empowers individuals to challenge injustice, advocate for their rights, and contribute to a more equitable and just world. Ultimately, education is not merely an investment in individuals, but an indispensable investment in the future of humanity itself.||

# %%
responses = model.batch([
    "What is the capital of France?",
    "What is the capital of Germany?",
    "What is the capital of Italy?"
])

for response in responses:
    print(response.content)
# Out:
# The capital of France is **Paris**.
# The capital of Germany is **Berlin**.
# The capital of Italy is **Rome**.

# %%
responses = model.batch([
    "What is the capital of France?",
    "What is the capital of Germany?",
    "What is the capital of Italy?"

] ,
{'max_concurrency': 2}
)

for response in responses:
    print(response.content)
# Out:
# The capital of France is **Paris**.
# The capital of Germany is **Berlin**.
# The capital of Italy is **Rome**.
